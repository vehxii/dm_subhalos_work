# %% [markdown]
# The goal of this notebook is to figure out how to calculate the infall times of subhalos onto "massive progenitors" and onto the "main host"
# Main goals:
# * t_infall_anything_bigger = time or snapshot when the subhalo under scrutiny falls into *any* more massive object (massive progenitor or main host). This would be "first_infall_snap" in the Symphony halo-level data (don't know where exactly yet).
# * t_infall_main_host = time when the subhalo under scrutiny falls into *specifically* the main host. This would be "merger_snap" in the Symphony halo-level data, in the "hist" (time-independent) data.
# * t_disrupt = time when the subhalo under scrutiny falls below the density required for ROCKSTAR to designate it a subhalo (300 particles)
#
# Using these:
# * Create probability density functions (basically histograms) where the infall times are sorted into time bins, allowing us to see if/when the distribution of infall times is peaked and how it behaves across different mass ranges. It would be good to make one version that is not normalized to host formation time, and another that is.
# * Create a plot using an autocorrelation function to measure how correlated the infall times of the "massive progenitor" are with the other subhalos (both field and associated I assume? This is the one I'm less clear on). It may also be useful to have a version that shows this effect but for different lines of sight. Autocorrelation should be giving a characteristic time interval for subhalo infalls.
# * Calculate the "preprocessed fraction," in other words the number of subhalos that fall onto something else before falling onto the MW, divided by the total number
# * Make a plot comparing the location/slope of the SHMF (before and after a particular massive infall), and the other side showing the change in the subhalo count of the massive infalls (GSE, LMC). Would be good to put side-by-side.
# * Cross-correlation function (?)

# %%
## packages and globals

import symlib
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import sys
import os
from matplotlib import colormaps
import matplotlib.colors as mcolors
from symlib.util import DEFAULT_HALO_NAMES

# %%
## GLOBALS
base_dir = "C:/Users/steph/Symphony"
suite_list = ["SymphonyLMC", "SymphonyMilkyWay", "SymphonyGroup", "SymphonyLCluster", "SymphonyCluster"]
colors = ["tab:purple", "tab:blue", "tab:green", "tab:orange", "tab:red"]
alt_colors = ["#6020a8", "#0e5b8f", "#1e8f0a", "#db5f07", "#ad0303"]

#suite_list = ["SymphonyMilkyWay"]
#colors = ["tab:blue"]
#alt_colors = ["#0e5b8f"]

# %% [markdown]
# The function "load_infall_data" below is supposed to read in subhalo infall times, sorted into two categories:
# 1. Infall times corresponding to when subhalos fell into specifically the *main host.* This includes subhalos that fell into a larger subhalo before falling into the main host. This field is read in using hist["merger_snap"]
# 2. Infall times corresponding to when subhalos fell into *any halo larger than themselves.*
#
# Prior to sorting, subhalos are also filtered using a 300 particle mass cut to reduce noise, and are also checked that they exist at the infall snapshot using the "ok" filter. To check that these cuts are working, the function also spits out how many subhalos were removed by the filter on a per-host and a per-suite basis.

# %%
## SUBHALO INFALL DATALOADER FUNCTION:
##
## Key quantities:
##    merger_snap         --> first infall into main host
##    first_infall_snap   --> first infall into ANY halo larger than itself

def load_infall_data(base_dir, suite_list):

    suite_data = {}

    for suite in suite_list:

        print(f"\nLoading suite: {suite}")

        halo_names = DEFAULT_HALO_NAMES[suite]

        ## reading in a global set of scale factors for this suite
        sim_dir0 = symlib.get_host_directory(base_dir, suite, 0)
        scale_factors = symlib.scale_factors(sim_dir0)
        nbins_suite = len(scale_factors)

        ## storing the per-host data
        hosts = []
        #suite_preprocessing_fractions = []

        
        for halo_index, halo_name in enumerate(halo_names):

            print(f"\nHalo {halo_index + 1}/{len(halo_names)}: {halo_name}", end = "\r", flush = True)

            sim_dir = symlib.get_host_directory(base_dir, suite, halo_name)
            h, hist = symlib.read_subhalos(sim_dir)
            params = symlib.simulation_parameters(sim_dir)

            ## basic quantities: particle mass, virial mass, "ok" array, and "MAIN HOST" & "ANYTHING LARGER" INFALL DATA:
            mp = params["mp"]                                 ## particle mass used for this suite
            host_infall_snap = hist["merger_snap"]            ## when subhalos fell into the main host
            first_infall_snap = hist["first_infall_snap"]     ## when subhalos fell into anything more massive than itself

            mvir = h["mvir"]     ## shape (# of subhalos, # of snapshots)
            ok = h["ok"]         ## shape (# of subhalos, # of snapshots)

            
            ## MAIN HOST INFALL MASK
            ## keep only subhalos which:
            ##   1. have valid infall snapshot (not interested in the main host behavior at the moment)
            ##   2. have infall mass greater than >= 300 particle masses
            ##   3. exist AT the infall snapshot (as determined by Rockstar/Symlib)

            ## INFALL INTO MAIN HOST:
            print(f"\nINFALL INTO MAIN HOST:")
            print(f"# of subhalos before masking:                     {len(host_infall_snap)}")

            ## removing the main host (always at snap = 0, biases results)
            host_infall_no_main = host_infall_snap > 0                                       ## removing the main host
            host_infall_rows_no_main = np.where(host_infall_no_main)[0]                      ## subhalo indices, excluding the main host
            host_infall_snaps_no_main = host_infall_snap[host_infall_no_main].astype(int)    ## subhalo infall snapshots, excluding the main host

            ## should just be 1 less than before
            print(f"# of subhalos, excluding the main host:           {len(host_infall_snaps_no_main)}, {len(host_infall_snap) - len(host_infall_snaps_no_main)} removed")

            ## mass cut, removing subhalos below a 300 particle mass resolution limit
            mass_cut = mvir[host_infall_rows_no_main, host_infall_snaps_no_main] >= 300 * mp
            host_infall_rows_mass_ok = host_infall_rows_no_main[mass_cut]
            host_infall_snaps_mass_ok = host_infall_snaps_no_main[mass_cut]
            print(f"# of subhalos, after the 300 particle mass cut:   {len(host_infall_snaps_mass_ok)}, {len(host_infall_snaps_no_main) - len(host_infall_snaps_mass_ok)} removed")

            ## subhalo survival cut: does the subhalo exist AT the infall snapshot?
            ok_cut = ok[host_infall_rows_mass_ok, host_infall_snaps_mass_ok]
            host_infall_rows_ok = host_infall_rows_mass_ok[ok_cut]
            host_infall_snaps_ok = host_infall_snaps_mass_ok[ok_cut]
            print(f"# of subhalos, after the ok survival cut:         {len(host_infall_snaps_ok)}, {len(host_infall_snaps_ok) - len(host_infall_snaps_mass_ok)} removed")
            print(f"# of subhalos removed:                                 {len(host_infall_snap) - len(host_infall_snaps_ok)} removed")
            

            ## INFALL INTO ANYTHING LARGER (same as above):
            print(f"\nINFALL INTO ANYTHING LARGER:")
            print(f"# of subhalos before masking:                     {len(first_infall_snap)}")
            first_infall_no_main = first_infall_snap > 0
            first_infall_rows_no_main = np.where(first_infall_no_main)[0]
            first_infall_snaps_no_main = first_infall_snap[first_infall_no_main].astype(int)
            print(f"# of subhalos, excluding the main host:           {len(first_infall_snaps_no_main)}, {len(first_infall_snap) - len(first_infall_snaps_no_main)} removed")   
            
            mass_cut = mvir[first_infall_rows_no_main, first_infall_snaps_no_main] >= 300 * mp
            first_infall_rows_mass_ok = first_infall_rows_no_main[mass_cut]
            first_infall_snaps_mass_ok = first_infall_snaps_no_main[mass_cut]
            print(f"# of subhalos, after the 300 particle mass cut:   {len(first_infall_snaps_mass_ok)}, {len(first_infall_snaps_no_main) - len(first_infall_snaps_mass_ok)} removed")

            ok_cut = ok[first_infall_rows_mass_ok, first_infall_snaps_mass_ok]
            first_infall_rows_ok = first_infall_rows_mass_ok[ok_cut]
            first_infall_snaps_ok = first_infall_snaps_mass_ok[ok_cut]
            print(f"# of subhalos, after the ok survival cut:         {len(first_infall_snaps_ok)}, {len(first_infall_snaps_ok) - len(first_infall_snaps_mass_ok)} removed")
            print(f"# of subhalos removed:                                 {len(first_infall_snap) - len(first_infall_snaps_ok)} removed")


            ## scale factors:
            host_infall_sf = scale_factors[host_infall_snaps_ok]
            first_infall_sf = scale_factors[first_infall_snaps_ok]

            ## subhalo masses at infall:
            host_infall_mpeak = hist["mpeak"][host_infall_rows_ok]
            first_infall_mpeak = hist["mpeak"][first_infall_rows_ok]
            
            ## PREPROCESSING FRACTIONS:
            ## of this sample of subhalos that are NOT the main host, are above the 300 particle limit, AND are marked as "ok" by the halo finders,
            ## how many of them fell into something larger before falling into the main host?
            ## a subhalo is "preprocessed" if first_infall_snap < host_infall_snap

            # use final surviving host infall sample as reference
            rows = host_infall_rows_ok
            host_snap = host_infall_snaps_ok
            
            # map first_infall to same rows
            first_snap = first_infall_snap[rows].astype(int)
            
            # preprocessing condition
            preprocessed = first_snap < host_snap
            
            # safe mask (in case any invalid entries slipped through)
            valid = np.isfinite(first_snap) & np.isfinite(host_snap)
            
            preprocessed = preprocessed[valid]
            preprocessing_fraction = np.mean(preprocessed)    ## computing the fraction from the number of "True" divided by the total # of entries in the array
            #suite_preprocessing_fractions.append(preprocessing_fraction)
            
            print(f"\nPREPROCESSING FRACTION:")
            print(f"  Preprocessed fraction: {preprocessing_fraction:.4f}")
            print(f"\n##############################################################################################################################")

            
            ## NORMALIZATION USING A50:
            host_mvir = mvir[0, :]                      ## getting the host peak mass
            peak_mass = np.max(host_mvir)
            cross = np.where(host_mvir >= 0.5 * peak_mass)[0]     ## finding the snapshot when the host crossed over its 50% peak mass threshold

            ## SAFE NORMALIZATION
            if len(cross) == 0:
                a50 = np.nan
            else:
                a50 = scale_factors[cross[0]]

            if not np.isfinite(a50) or a50 <= 0:
                host_infall_sf_norm = np.full_like(host_infall_sf, np.nan)
                first_infall_sf_norm  = np.full_like(first_infall_sf, np.nan)
            else:
                host_infall_sf_norm = host_infall_sf / a50
                first_infall_sf_norm  = first_infall_sf / a50

            
            ## counting up # of subhalos per time bin

            ## HOST INFALL and ANYTHING LARGER counting:
            host_infall_counts = np.zeros(nbins_suite)

            if len(host_infall_snaps_ok) > 0:
                u, c = np.unique(host_infall_snaps_ok, return_counts = True)
                host_infall_counts[u] = c

            first_infall_counts = np.zeros(nbins_suite)
            
            if len(first_infall_snaps_ok) > 0:
                u, c = np.unique(first_infall_snaps_ok, return_counts = True)
                first_infall_counts[u] = c


            ## STORING HOST DATA
            host_data = {

                ## MAIN HOST INFALL TIMES AND MASSES
                "host_infall_sf": host_infall_sf,
                "host_infall_sf_norm": host_infall_sf_norm,
                "host_infall_mpeak": host_infall_mpeak,
                "host_infall_counts": host_infall_counts,

                ## FIRST INFALL TIMES AND MASSES
                "first_infall_sf": first_infall_sf,
                "first_infall_sf_norm": first_infall_sf_norm,
                "first_infall_mpeak": first_infall_mpeak,
                "first_infall_counts": first_infall_counts,

                ## PREPROCESSING
                "preprocessing_fraction": preprocessing_fraction,

                ## HOST PROPERTIES
                "host_mass": peak_mass,
                "a50": a50
            }

            hosts.append(host_data)

        ## STORING PER-SUITE DATA
        suite_data[suite] = {"scale_factors": scale_factors, "hosts": hosts}

        print(f"\nSUITE PREPROCESSING SUMMARY")
        fractions = [h["preprocessing_fraction"] for h in hosts]
        print(f"Mean per-halo fraction:   {(np.mean(fractions) * 100):.2f}%")
        print(f"Median per-halo fraction: {(np.median(fractions) * 100):.2f}%")

        print(f"\nFinished suite: {suite} ({len(hosts)} halos)")
        print(f"========================================================================================================================")

    return suite_data

# %%
## load data once
suite_data = load_infall_data(base_dir, suite_list)
# Out:
# Loading suite: SymphonyLMC
#
# Halo 1/39: Halo032
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     218
# # of subhalos, excluding the main host:           217, 1 removed
# # of subhalos, after the 300 particle mass cut:   161, 56 removed
# # of subhalos, after the ok survival cut:         161, 0 removed
# # of subhalos removed:                                 57 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     218
# # of subhalos, excluding the main host:           217, 1 removed
# # of subhalos, after the 300 particle mass cut:   192, 25 removed
# # of subhalos, after the ok survival cut:         192, 0 removed
# # of subhalos removed:                                 26 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3043
#
# ##############################################################################################################################
#
# Halo 2/39: Halo059
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     322
# # of subhalos, excluding the main host:           321, 1 removed
# # of subhalos, after the 300 particle mass cut:   259, 62 removed
# # of subhalos, after the ok survival cut:         259, 0 removed
# # of subhalos removed:                                 63 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     322
# # of subhalos, excluding the main host:           321, 1 removed
# # of subhalos, after the 300 particle mass cut:   317, 4 removed
# # of subhalos, after the ok survival cut:         317, 0 removed
# # of subhalos removed:                                 5 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.5212
#
# ##############################################################################################################################
#
# Halo 3/39: Halo0662
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     305
# # of subhalos, excluding the main host:           304, 1 removed
# # of subhalos, after the 300 particle mass cut:   251, 53 removed
# # of subhalos, after the ok survival cut:         251, 0 removed
# # of subhalos removed:                                 54 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     305
# # of subhalos, excluding the main host:           304, 1 removed
# # of subhalos, after the 300 particle mass cut:   293, 11 removed
# # of subhalos, after the ok survival cut:         293, 0 removed
# # of subhalos removed:                                 12 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3665
#
# ##############################################################################################################################
#
# Halo 4/39: Halo083
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     268
# # of subhalos, excluding the main host:           267, 1 removed
# # of subhalos, after the 300 particle mass cut:   223, 44 removed
# # of subhalos, after the ok survival cut:         223, 0 removed
# # of subhalos removed:                                 45 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     268
# # of subhalos, excluding the main host:           267, 1 removed
# # of subhalos, after the 300 particle mass cut:   263, 4 removed
# # of subhalos, after the ok survival cut:         263, 0 removed
# # of subhalos removed:                                 5 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.2691
#
# ##############################################################################################################################
#
# Halo 5/39: Halo088
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     354
# # of subhalos, excluding the main host:           353, 1 removed
# # of subhalos, after the 300 particle mass cut:   274, 79 removed
# # of subhalos, after the ok survival cut:         274, 0 removed
# # of subhalos removed:                                 80 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     354
# # of subhalos, excluding the main host:           353, 1 removed
# # of subhalos, after the 300 particle mass cut:   348, 5 removed
# # of subhalos, after the ok survival cut:         348, 0 removed
# # of subhalos removed:                                 6 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4927
#
# ##############################################################################################################################
#
# Halo 6/39: Halo097
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     380
# # of subhalos, excluding the main host:           379, 1 removed
# # of subhalos, after the 300 particle mass cut:   323, 56 removed
# # of subhalos, after the ok survival cut:         323, 0 removed
# # of subhalos removed:                                 57 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     380
# # of subhalos, excluding the main host:           379, 1 removed
# # of subhalos, after the 300 particle mass cut:   373, 6 removed
# # of subhalos, after the ok survival cut:         373, 0 removed
# # of subhalos removed:                                 7 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4303
#
# ##############################################################################################################################
#
# Halo 7/39: Halo104
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     320
# # of subhalos, excluding the main host:           319, 1 removed
# # of subhalos, after the 300 particle mass cut:   278, 41 removed
# # of subhalos, after the ok survival cut:         278, 0 removed
# # of subhalos removed:                                 42 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     320
# # of subhalos, excluding the main host:           319, 1 removed
# # of subhalos, after the 300 particle mass cut:   317, 2 removed
# # of subhalos, after the ok survival cut:         317, 0 removed
# # of subhalos removed:                                 3 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3022
#
# ##############################################################################################################################
#
# Halo 8/39: Halo110
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     365
# # of subhalos, excluding the main host:           364, 1 removed
# # of subhalos, after the 300 particle mass cut:   319, 45 removed
# # of subhalos, after the ok survival cut:         319, 0 removed
# # of subhalos removed:                                 46 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     365
# # of subhalos, excluding the main host:           364, 1 removed
# # of subhalos, after the 300 particle mass cut:   356, 8 removed
# # of subhalos, after the ok survival cut:         356, 0 removed
# # of subhalos removed:                                 9 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.2884
#
# ##############################################################################################################################
#
# Halo 9/39: Halo202
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     320
# # of subhalos, excluding the main host:           319, 1 removed
# # of subhalos, after the 300 particle mass cut:   277, 42 removed
# # of subhalos, after the ok survival cut:         277, 0 removed
# # of subhalos removed:                                 43 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     320
# # of subhalos, excluding the main host:           319, 1 removed
# # of subhalos, after the 300 particle mass cut:   310, 9 removed
# # of subhalos, after the ok survival cut:         310, 0 removed
# # of subhalos removed:                                 10 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4116
#
# ##############################################################################################################################
#
# Halo 10/39: Halo208
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     307
# # of subhalos, excluding the main host:           306, 1 removed
# # of subhalos, after the 300 particle mass cut:   246, 60 removed
# # of subhalos, after the ok survival cut:         246, 0 removed
# # of subhalos removed:                                 61 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     307
# # of subhalos, excluding the main host:           306, 1 removed
# # of subhalos, after the 300 particle mass cut:   300, 6 removed
# # of subhalos, after the ok survival cut:         300, 0 removed
# # of subhalos removed:                                 7 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3455
#
# ##############################################################################################################################
#
# Halo 11/39: Halo218
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     387
# # of subhalos, excluding the main host:           386, 1 removed
# # of subhalos, after the 300 particle mass cut:   335, 51 removed
# # of subhalos, after the ok survival cut:         335, 0 removed
# # of subhalos removed:                                 52 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     387
# # of subhalos, excluding the main host:           386, 1 removed
# # of subhalos, after the 300 particle mass cut:   380, 6 removed
# # of subhalos, after the ok survival cut:         380, 0 removed
# # of subhalos removed:                                 7 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4299
#
# ##############################################################################################################################
#
# Halo 12/39: Halo296
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     351
# # of subhalos, excluding the main host:           350, 1 removed
# # of subhalos, after the 300 particle mass cut:   281, 69 removed
# # of subhalos, after the ok survival cut:         281, 0 removed
# # of subhalos removed:                                 70 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     351
# # of subhalos, excluding the main host:           350, 1 removed
# # of subhalos, after the 300 particle mass cut:   343, 7 removed
# # of subhalos, after the ok survival cut:         343, 0 removed
# # of subhalos removed:                                 8 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.5480
#
# ##############################################################################################################################
#
# Halo 13/39: Halo301
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     353
# # of subhalos, excluding the main host:           352, 1 removed
# # of subhalos, after the 300 particle mass cut:   295, 57 removed
# # of subhalos, after the ok survival cut:         295, 0 removed
# # of subhalos removed:                                 58 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     353
# # of subhalos, excluding the main host:           352, 1 removed
# # of subhalos, after the 300 particle mass cut:   344, 8 removed
# # of subhalos, after the ok survival cut:         344, 0 removed
# # of subhalos removed:                                 9 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4576
#
# ##############################################################################################################################
#
# Halo 14/39: Halo303
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     373
# # of subhalos, excluding the main host:           372, 1 removed
# # of subhalos, after the 300 particle mass cut:   294, 78 removed
# # of subhalos, after the ok survival cut:         294, 0 removed
# # of subhalos removed:                                 79 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     373
# # of subhalos, excluding the main host:           372, 1 removed
# # of subhalos, after the 300 particle mass cut:   367, 5 removed
# # of subhalos, after the ok survival cut:         367, 0 removed
# # of subhalos removed:                                 6 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4286
#
# ##############################################################################################################################
#
# Halo 15/39: Halo340
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     362
# # of subhalos, excluding the main host:           361, 1 removed
# # of subhalos, after the 300 particle mass cut:   308, 53 removed
# # of subhalos, after the ok survival cut:         308, 0 removed
# # of subhalos removed:                                 54 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     362
# # of subhalos, excluding the main host:           361, 1 removed
# # of subhalos, after the 300 particle mass cut:   355, 6 removed
# # of subhalos, after the ok survival cut:         355, 0 removed
# # of subhalos removed:                                 7 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3377
#
# ##############################################################################################################################
#
# Halo 16/39: Halo374
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     341
# # of subhalos, excluding the main host:           340, 1 removed
# # of subhalos, after the 300 particle mass cut:   283, 57 removed
# # of subhalos, after the ok survival cut:         283, 0 removed
# # of subhalos removed:                                 58 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     341
# # of subhalos, excluding the main host:           340, 1 removed
# # of subhalos, after the 300 particle mass cut:   336, 4 removed
# # of subhalos, after the ok survival cut:         336, 0 removed
# # of subhalos removed:                                 5 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4417
#
# ##############################################################################################################################
#
# Halo 17/39: Halo380
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     401
# # of subhalos, excluding the main host:           400, 1 removed
# # of subhalos, after the 300 particle mass cut:   336, 64 removed
# # of subhalos, after the ok survival cut:         336, 0 removed
# # of subhalos removed:                                 65 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     401
# # of subhalos, excluding the main host:           400, 1 removed
# # of subhalos, after the 300 particle mass cut:   396, 4 removed
# # of subhalos, after the ok survival cut:         396, 0 removed
# # of subhalos removed:                                 5 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.2738
#
# ##############################################################################################################################
#
# Halo 18/39: Halo391
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     358
# # of subhalos, excluding the main host:           357, 1 removed
# # of subhalos, after the 300 particle mass cut:   292, 65 removed
# # of subhalos, after the ok survival cut:         292, 0 removed
# # of subhalos removed:                                 66 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     358
# # of subhalos, excluding the main host:           357, 1 removed
# # of subhalos, after the 300 particle mass cut:   352, 5 removed
# # of subhalos, after the ok survival cut:         352, 0 removed
# # of subhalos removed:                                 6 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3733
#
# ##############################################################################################################################
#
# Halo 19/39: Halo405
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     386
# # of subhalos, excluding the main host:           385, 1 removed
# # of subhalos, after the 300 particle mass cut:   344, 41 removed
# # of subhalos, after the ok survival cut:         344, 0 removed
# # of subhalos removed:                                 42 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     386
# # of subhalos, excluding the main host:           385, 1 removed
# # of subhalos, after the 300 particle mass cut:   380, 5 removed
# # of subhalos, after the ok survival cut:         380, 0 removed
# # of subhalos removed:                                 6 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3692
#
# ##############################################################################################################################
#
# Halo 20/39: Halo440
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     265
# # of subhalos, excluding the main host:           264, 1 removed
# # of subhalos, after the 300 particle mass cut:   218, 46 removed
# # of subhalos, after the ok survival cut:         218, 0 removed
# # of subhalos removed:                                 47 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     265
# # of subhalos, excluding the main host:           264, 1 removed
# # of subhalos, after the 300 particle mass cut:   262, 2 removed
# # of subhalos, after the ok survival cut:         262, 0 removed
# # of subhalos removed:                                 3 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4312
#
# ##############################################################################################################################
#
# Halo 21/39: Halo463
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     291
# # of subhalos, excluding the main host:           290, 1 removed
# # of subhalos, after the 300 particle mass cut:   223, 67 removed
# # of subhalos, after the ok survival cut:         223, 0 removed
# # of subhalos removed:                                 68 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     291
# # of subhalos, excluding the main host:           290, 1 removed
# # of subhalos, after the 300 particle mass cut:   287, 3 removed
# # of subhalos, after the ok survival cut:         287, 0 removed
# # of subhalos removed:                                 4 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3722
#
# ##############################################################################################################################
#
# Halo 22/39: Halo4662
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     290
# # of subhalos, excluding the main host:           289, 1 removed
# # of subhalos, after the 300 particle mass cut:   237, 52 removed
# # of subhalos, after the ok survival cut:         237, 0 removed
# # of subhalos removed:                                 53 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     290
# # of subhalos, excluding the main host:           289, 1 removed
# # of subhalos, after the 300 particle mass cut:   287, 2 removed
# # of subhalos, after the ok survival cut:         287, 0 removed
# # of subhalos removed:                                 3 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4557
#
# ##############################################################################################################################
#
# Halo 23/39: Halo511
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     330
# # of subhalos, excluding the main host:           329, 1 removed
# # of subhalos, after the 300 particle mass cut:   288, 41 removed
# # of subhalos, after the ok survival cut:         288, 0 removed
# # of subhalos removed:                                 42 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     330
# # of subhalos, excluding the main host:           329, 1 removed
# # of subhalos, after the 300 particle mass cut:   319, 10 removed
# # of subhalos, after the ok survival cut:         319, 0 removed
# # of subhalos removed:                                 11 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3958
#
# ##############################################################################################################################
#
# Halo 24/39: Halo524
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     286
# # of subhalos, excluding the main host:           285, 1 removed
# # of subhalos, after the 300 particle mass cut:   232, 53 removed
# # of subhalos, after the ok survival cut:         232, 0 removed
# # of subhalos removed:                                 54 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     286
# # of subhalos, excluding the main host:           285, 1 removed
# # of subhalos, after the 300 particle mass cut:   282, 3 removed
# # of subhalos, after the ok survival cut:         282, 0 removed
# # of subhalos removed:                                 4 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3534
#
# ##############################################################################################################################
#
# Halo 25/39: Halo539
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     256
# # of subhalos, excluding the main host:           255, 1 removed
# # of subhalos, after the 300 particle mass cut:   192, 63 removed
# # of subhalos, after the ok survival cut:         192, 0 removed
# # of subhalos removed:                                 64 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     256
# # of subhalos, excluding the main host:           255, 1 removed
# # of subhalos, after the 300 particle mass cut:   246, 9 removed
# # of subhalos, after the ok survival cut:         246, 0 removed
# # of subhalos removed:                                 10 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4010
#
# ##############################################################################################################################
#
# Halo 26/39: Halo567
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     322
# # of subhalos, excluding the main host:           321, 1 removed
# # of subhalos, after the 300 particle mass cut:   269, 52 removed
# # of subhalos, after the ok survival cut:         269, 0 removed
# # of subhalos removed:                                 53 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     322
# # of subhalos, excluding the main host:           321, 1 removed
# # of subhalos, after the 300 particle mass cut:   316, 5 removed
# # of subhalos, after the ok survival cut:         316, 0 removed
# # of subhalos removed:                                 6 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3792
#
# ##############################################################################################################################
#
# Halo 27/39: Halo575
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     372
# # of subhalos, excluding the main host:           371, 1 removed
# # of subhalos, after the 300 particle mass cut:   329, 42 removed
# # of subhalos, after the ok survival cut:         329, 0 removed
# # of subhalos removed:                                 43 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     372
# # of subhalos, excluding the main host:           371, 1 removed
# # of subhalos, after the 300 particle mass cut:   365, 6 removed
# # of subhalos, after the ok survival cut:         365, 0 removed
# # of subhalos removed:                                 7 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3313
#
# ##############################################################################################################################
#
# Halo 28/39: Halo602
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     385
# # of subhalos, excluding the main host:           384, 1 removed
# # of subhalos, after the 300 particle mass cut:   333, 51 removed
# # of subhalos, after the ok survival cut:         333, 0 removed
# # of subhalos removed:                                 52 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     385
# # of subhalos, excluding the main host:           384, 1 removed
# # of subhalos, after the 300 particle mass cut:   376, 8 removed
# # of subhalos, after the ok survival cut:         376, 0 removed
# # of subhalos removed:                                 9 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4655
#
# ##############################################################################################################################
#
# Halo 29/39: Halo697
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     220
# # of subhalos, excluding the main host:           219, 1 removed
# # of subhalos, after the 300 particle mass cut:   183, 36 removed
# # of subhalos, after the ok survival cut:         183, 0 removed
# # of subhalos removed:                                 37 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     220
# # of subhalos, excluding the main host:           219, 1 removed
# # of subhalos, after the 300 particle mass cut:   211, 8 removed
# # of subhalos, after the ok survival cut:         211, 0 removed
# # of subhalos removed:                                 9 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.2951
#
# ##############################################################################################################################
#
# Halo 30/39: Halo711
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     336
# # of subhalos, excluding the main host:           335, 1 removed
# # of subhalos, after the 300 particle mass cut:   295, 40 removed
# # of subhalos, after the ok survival cut:         295, 0 removed
# # of subhalos removed:                                 41 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     336
# # of subhalos, excluding the main host:           335, 1 removed
# # of subhalos, after the 300 particle mass cut:   330, 5 removed
# # of subhalos, after the ok survival cut:         330, 0 removed
# # of subhalos removed:                                 6 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.2983
#
# ##############################################################################################################################
#
# Halo 31/39: Halo721
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     301
# # of subhalos, excluding the main host:           300, 1 removed
# # of subhalos, after the 300 particle mass cut:   255, 45 removed
# # of subhalos, after the ok survival cut:         255, 0 removed
# # of subhalos removed:                                 46 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     301
# # of subhalos, excluding the main host:           300, 1 removed
# # of subhalos, after the 300 particle mass cut:   294, 6 removed
# # of subhalos, after the ok survival cut:         294, 0 removed
# # of subhalos removed:                                 7 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3137
#
# ##############################################################################################################################
#
# Halo 32/39: Halo767
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     361
# # of subhalos, excluding the main host:           360, 1 removed
# # of subhalos, after the 300 particle mass cut:   318, 42 removed
# # of subhalos, after the ok survival cut:         318, 0 removed
# # of subhalos removed:                                 43 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     361
# # of subhalos, excluding the main host:           360, 1 removed
# # of subhalos, after the 300 particle mass cut:   354, 6 removed
# # of subhalos, after the ok survival cut:         354, 0 removed
# # of subhalos removed:                                 7 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3553
#
# ##############################################################################################################################
#
# Halo 33/39: Halo802
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     279
# # of subhalos, excluding the main host:           278, 1 removed
# # of subhalos, after the 300 particle mass cut:   241, 37 removed
# # of subhalos, after the ok survival cut:         241, 0 removed
# # of subhalos removed:                                 38 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     279
# # of subhalos, excluding the main host:           278, 1 removed
# # of subhalos, after the 300 particle mass cut:   273, 5 removed
# # of subhalos, after the ok survival cut:         273, 0 removed
# # of subhalos removed:                                 6 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4108
#
# ##############################################################################################################################
#
# Halo 34/39: Halo824
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     385
# # of subhalos, excluding the main host:           384, 1 removed
# # of subhalos, after the 300 particle mass cut:   341, 43 removed
# # of subhalos, after the ok survival cut:         341, 0 removed
# # of subhalos removed:                                 44 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     385
# # of subhalos, excluding the main host:           384, 1 removed
# # of subhalos, after the 300 particle mass cut:   381, 3 removed
# # of subhalos, after the ok survival cut:         381, 0 removed
# # of subhalos removed:                                 4 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3666
#
# ##############################################################################################################################
#
# Halo 35/39: Halo850
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     354
# # of subhalos, excluding the main host:           353, 1 removed
# # of subhalos, after the 300 particle mass cut:   298, 55 removed
# # of subhalos, after the ok survival cut:         298, 0 removed
# # of subhalos removed:                                 56 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     354
# # of subhalos, excluding the main host:           353, 1 removed
# # of subhalos, after the 300 particle mass cut:   349, 4 removed
# # of subhalos, after the ok survival cut:         349, 0 removed
# # of subhalos removed:                                 5 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3758
#
# ##############################################################################################################################
#
# Halo 36/39: Halo853
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     405
# # of subhalos, excluding the main host:           404, 1 removed
# # of subhalos, after the 300 particle mass cut:   360, 44 removed
# # of subhalos, after the ok survival cut:         360, 0 removed
# # of subhalos removed:                                 45 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     405
# # of subhalos, excluding the main host:           404, 1 removed
# # of subhalos, after the 300 particle mass cut:   395, 9 removed
# # of subhalos, after the ok survival cut:         395, 0 removed
# # of subhalos removed:                                 10 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3222
#
# ##############################################################################################################################
#
# Halo 37/39: Halo914
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     376
# # of subhalos, excluding the main host:           375, 1 removed
# # of subhalos, after the 300 particle mass cut:   320, 55 removed
# # of subhalos, after the ok survival cut:         320, 0 removed
# # of subhalos removed:                                 56 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     376
# # of subhalos, excluding the main host:           375, 1 removed
# # of subhalos, after the 300 particle mass cut:   356, 19 removed
# # of subhalos, after the ok survival cut:         356, 0 removed
# # of subhalos removed:                                 20 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3750
#
# ##############################################################################################################################
#
# Halo 38/39: Halo932
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     321
# # of subhalos, excluding the main host:           320, 1 removed
# # of subhalos, after the 300 particle mass cut:   260, 60 removed
# # of subhalos, after the ok survival cut:         260, 0 removed
# # of subhalos removed:                                 61 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     321
# # of subhalos, excluding the main host:           320, 1 removed
# # of subhalos, after the 300 particle mass cut:   315, 5 removed
# # of subhalos, after the ok survival cut:         315, 0 removed
# # of subhalos removed:                                 6 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4577
#
# ##############################################################################################################################
#
# Halo 39/39: Halo933
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     189
# # of subhalos, excluding the main host:           188, 1 removed
# # of subhalos, after the 300 particle mass cut:   157, 31 removed
# # of subhalos, after the ok survival cut:         157, 0 removed
# # of subhalos removed:                                 32 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     189
# # of subhalos, excluding the main host:           188, 1 removed
# # of subhalos, after the 300 particle mass cut:   181, 7 removed
# # of subhalos, after the ok survival cut:         181, 0 removed
# # of subhalos removed:                                 8 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.2803
#
# ##############################################################################################################################
#
# SUITE PREPROCESSING SUMMARY
# Mean per-halo fraction:   38.02%
# Median per-halo fraction: 37.33%
#
# Finished suite: SymphonyLMC (39 halos)
# ========================================================================================================================
#
# Loading suite: SymphonyMilkyWay
#
# Halo 1/45: Halo023
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     419
# # of subhalos, excluding the main host:           418, 1 removed
# # of subhalos, after the 300 particle mass cut:   359, 59 removed
# # of subhalos, after the ok survival cut:         359, 0 removed
# # of subhalos removed:                                 60 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     419
# # of subhalos, excluding the main host:           418, 1 removed
# # of subhalos, after the 300 particle mass cut:   411, 7 removed
# # of subhalos, after the ok survival cut:         411, 0 removed
# # of subhalos removed:                                 8 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3955
#
# ##############################################################################################################################
#
# Halo 2/45: Halo088
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     598
# # of subhalos, excluding the main host:           597, 1 removed
# # of subhalos, after the 300 particle mass cut:   448, 149 removed
# # of subhalos, after the ok survival cut:         448, 0 removed
# # of subhalos removed:                                 150 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     598
# # of subhalos, excluding the main host:           597, 1 removed
# # of subhalos, after the 300 particle mass cut:   593, 4 removed
# # of subhalos, after the ok survival cut:         593, 0 removed
# # of subhalos removed:                                 5 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.5848
#
# ##############################################################################################################################
#
# Halo 3/45: Halo119
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     489
# # of subhalos, excluding the main host:           488, 1 removed
# # of subhalos, after the 300 particle mass cut:   362, 126 removed
# # of subhalos, after the ok survival cut:         362, 0 removed
# # of subhalos removed:                                 127 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     489
# # of subhalos, excluding the main host:           488, 1 removed
# # of subhalos, after the 300 particle mass cut:   479, 9 removed
# # of subhalos, after the ok survival cut:         479, 0 removed
# # of subhalos removed:                                 10 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.5939
#
# ##############################################################################################################################
#
# Halo 4/45: Halo188
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     432
# # of subhalos, excluding the main host:           431, 1 removed
# # of subhalos, after the 300 particle mass cut:   352, 79 removed
# # of subhalos, after the ok survival cut:         352, 0 removed
# # of subhalos removed:                                 80 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     432
# # of subhalos, excluding the main host:           431, 1 removed
# # of subhalos, after the 300 particle mass cut:   426, 5 removed
# # of subhalos, after the ok survival cut:         426, 0 removed
# # of subhalos removed:                                 6 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4801
#
# ##############################################################################################################################
#
# Halo 5/45: Halo247
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     562
# # of subhalos, excluding the main host:           561, 1 removed
# # of subhalos, after the 300 particle mass cut:   494, 67 removed
# # of subhalos, after the ok survival cut:         494, 0 removed
# # of subhalos removed:                                 68 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     562
# # of subhalos, excluding the main host:           561, 1 removed
# # of subhalos, after the 300 particle mass cut:   552, 9 removed
# # of subhalos, after the ok survival cut:         552, 0 removed
# # of subhalos removed:                                 10 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.2470
#
# ##############################################################################################################################
#
# Halo 6/45: Halo268
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     520
# # of subhalos, excluding the main host:           519, 1 removed
# # of subhalos, after the 300 particle mass cut:   453, 66 removed
# # of subhalos, after the ok survival cut:         453, 0 removed
# # of subhalos removed:                                 67 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     520
# # of subhalos, excluding the main host:           519, 1 removed
# # of subhalos, after the 300 particle mass cut:   515, 4 removed
# # of subhalos, after the ok survival cut:         515, 0 removed
# # of subhalos removed:                                 5 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3929
#
# ##############################################################################################################################
#
# Halo 7/45: Halo270
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     600
# # of subhalos, excluding the main host:           599, 1 removed
# # of subhalos, after the 300 particle mass cut:   487, 112 removed
# # of subhalos, after the ok survival cut:         487, 0 removed
# # of subhalos removed:                                 113 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     600
# # of subhalos, excluding the main host:           599, 1 removed
# # of subhalos, after the 300 particle mass cut:   587, 12 removed
# # of subhalos, after the ok survival cut:         587, 0 removed
# # of subhalos removed:                                 13 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.5749
#
# ##############################################################################################################################
#
# Halo 8/45: Halo288
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     448
# # of subhalos, excluding the main host:           447, 1 removed
# # of subhalos, after the 300 particle mass cut:   376, 71 removed
# # of subhalos, after the ok survival cut:         376, 0 removed
# # of subhalos removed:                                 72 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     448
# # of subhalos, excluding the main host:           447, 1 removed
# # of subhalos, after the 300 particle mass cut:   442, 5 removed
# # of subhalos, after the ok survival cut:         442, 0 removed
# # of subhalos removed:                                 6 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3856
#
# ##############################################################################################################################
#
# Halo 9/45: Halo327
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     410
# # of subhalos, excluding the main host:           409, 1 removed
# # of subhalos, after the 300 particle mass cut:   315, 94 removed
# # of subhalos, after the ok survival cut:         315, 0 removed
# # of subhalos removed:                                 95 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     410
# # of subhalos, excluding the main host:           409, 1 removed
# # of subhalos, after the 300 particle mass cut:   397, 12 removed
# # of subhalos, after the ok survival cut:         397, 0 removed
# # of subhalos removed:                                 13 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4413
#
# ##############################################################################################################################
#
# Halo 10/45: Halo349
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     493
# # of subhalos, excluding the main host:           492, 1 removed
# # of subhalos, after the 300 particle mass cut:   439, 53 removed
# # of subhalos, after the ok survival cut:         439, 0 removed
# # of subhalos removed:                                 54 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     493
# # of subhalos, excluding the main host:           492, 1 removed
# # of subhalos, after the 300 particle mass cut:   488, 4 removed
# # of subhalos, after the ok survival cut:         488, 0 removed
# # of subhalos removed:                                 5 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3759
#
# ##############################################################################################################################
#
# Halo 11/45: Halo364
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     506
# # of subhalos, excluding the main host:           505, 1 removed
# # of subhalos, after the 300 particle mass cut:   436, 69 removed
# # of subhalos, after the ok survival cut:         436, 0 removed
# # of subhalos removed:                                 70 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     506
# # of subhalos, excluding the main host:           505, 1 removed
# # of subhalos, after the 300 particle mass cut:   495, 10 removed
# # of subhalos, after the ok survival cut:         495, 0 removed
# # of subhalos removed:                                 11 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3394
#
# ##############################################################################################################################
#
# Halo 12/45: Halo374
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     508
# # of subhalos, excluding the main host:           507, 1 removed
# # of subhalos, after the 300 particle mass cut:   438, 69 removed
# # of subhalos, after the ok survival cut:         438, 0 removed
# # of subhalos removed:                                 70 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     508
# # of subhalos, excluding the main host:           507, 1 removed
# # of subhalos, after the 300 particle mass cut:   496, 11 removed
# # of subhalos, after the ok survival cut:         496, 0 removed
# # of subhalos removed:                                 12 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3516
#
# ##############################################################################################################################
#
# Halo 13/45: Halo414
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     439
# # of subhalos, excluding the main host:           438, 1 removed
# # of subhalos, after the 300 particle mass cut:   357, 81 removed
# # of subhalos, after the ok survival cut:         357, 0 removed
# # of subhalos removed:                                 82 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     439
# # of subhalos, excluding the main host:           438, 1 removed
# # of subhalos, after the 300 particle mass cut:   428, 10 removed
# # of subhalos, after the ok survival cut:         428, 0 removed
# # of subhalos removed:                                 11 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4594
#
# ##############################################################################################################################
#
# Halo 14/45: Halo415
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     544
# # of subhalos, excluding the main host:           542, 2 removed
# # of subhalos, after the 300 particle mass cut:   482, 60 removed
# # of subhalos, after the ok survival cut:         482, 0 removed
# # of subhalos removed:                                 62 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     544
# # of subhalos, excluding the main host:           542, 2 removed
# # of subhalos, after the 300 particle mass cut:   533, 9 removed
# # of subhalos, after the ok survival cut:         533, 0 removed
# # of subhalos removed:                                 11 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3216
#
# ##############################################################################################################################
#
# Halo 15/45: Halo416
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     546
# # of subhalos, excluding the main host:           545, 1 removed
# # of subhalos, after the 300 particle mass cut:   425, 120 removed
# # of subhalos, after the ok survival cut:         425, 0 removed
# # of subhalos removed:                                 121 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     546
# # of subhalos, excluding the main host:           545, 1 removed
# ...
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     784
# # of subhalos, excluding the main host:           783, 1 removed
# # of subhalos, after the 300 particle mass cut:   771, 12 removed
# # of subhalos, after the ok survival cut:         771, 0 removed
# # of subhalos removed:                                 13 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.5963
#
# ##############################################################################################################################
#
# Halo 65/81: Halo483
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     825
# # of subhalos, excluding the main host:           824, 1 removed
# # of subhalos, after the 300 particle mass cut:   674, 150 removed
# # of subhalos, after the ok survival cut:         674, 0 removed
# # of subhalos removed:                                 151 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     825
# # of subhalos, excluding the main host:           824, 1 removed
# # of subhalos, after the 300 particle mass cut:   809, 15 removed
# # of subhalos, after the ok survival cut:         809, 0 removed
# # of subhalos removed:                                 16 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.5237
#
# ##############################################################################################################################
#
# Halo 66/81: Halo489
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     970
# # of subhalos, excluding the main host:           969, 1 removed
# # of subhalos, after the 300 particle mass cut:   804, 165 removed
# # of subhalos, after the ok survival cut:         804, 0 removed
# # of subhalos removed:                                 166 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     970
# # of subhalos, excluding the main host:           969, 1 removed
# # of subhalos, after the 300 particle mass cut:   954, 15 removed
# # of subhalos, after the ok survival cut:         954, 0 removed
# # of subhalos removed:                                 16 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4552
#
# ##############################################################################################################################
#
# Halo 67/81: Halo494
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     777
# # of subhalos, excluding the main host:           776, 1 removed
# # of subhalos, after the 300 particle mass cut:   600, 176 removed
# # of subhalos, after the ok survival cut:         600, 0 removed
# # of subhalos removed:                                 177 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     777
# # of subhalos, excluding the main host:           777, 0 removed
# # of subhalos, after the 300 particle mass cut:   768, 9 removed
# # of subhalos, after the ok survival cut:         768, 0 removed
# # of subhalos removed:                                 9 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.6800
#
# ##############################################################################################################################
#
# Halo 68/81: Halo502
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     765
# # of subhalos, excluding the main host:           764, 1 removed
# # of subhalos, after the 300 particle mass cut:   579, 185 removed
# # of subhalos, after the ok survival cut:         579, 0 removed
# # of subhalos removed:                                 186 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     765
# # of subhalos, excluding the main host:           764, 1 removed
# # of subhalos, after the 300 particle mass cut:   753, 11 removed
# # of subhalos, after the ok survival cut:         753, 0 removed
# # of subhalos removed:                                 12 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.6425
#
# ##############################################################################################################################
#
# Halo 69/81: Halo517
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     791
# # of subhalos, excluding the main host:           790, 1 removed
# # of subhalos, after the 300 particle mass cut:   587, 203 removed
# # of subhalos, after the ok survival cut:         587, 0 removed
# # of subhalos removed:                                 204 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     791
# # of subhalos, excluding the main host:           790, 1 removed
# # of subhalos, after the 300 particle mass cut:   782, 8 removed
# # of subhalos, after the ok survival cut:         782, 0 removed
# # of subhalos removed:                                 9 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.6235
#
# ##############################################################################################################################
#
# Halo 70/81: Halo522
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     916
# # of subhalos, excluding the main host:           915, 1 removed
# # of subhalos, after the 300 particle mass cut:   745, 170 removed
# # of subhalos, after the ok survival cut:         745, 0 removed
# # of subhalos removed:                                 171 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     916
# # of subhalos, excluding the main host:           915, 1 removed
# # of subhalos, after the 300 particle mass cut:   903, 12 removed
# # of subhalos, after the ok survival cut:         903, 0 removed
# # of subhalos removed:                                 13 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.5785
#
# ##############################################################################################################################
#
# Halo 71/81: Halo544
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     872
# # of subhalos, excluding the main host:           871, 1 removed
# # of subhalos, after the 300 particle mass cut:   708, 163 removed
# # of subhalos, after the ok survival cut:         708, 0 removed
# # of subhalos removed:                                 164 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     872
# # of subhalos, excluding the main host:           871, 1 removed
# # of subhalos, after the 300 particle mass cut:   852, 19 removed
# # of subhalos, after the ok survival cut:         852, 0 removed
# # of subhalos removed:                                 20 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.5113
#
# ##############################################################################################################################
#
# Halo 72/81: Halo545
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     911
# # of subhalos, excluding the main host:           910, 1 removed
# # of subhalos, after the 300 particle mass cut:   736, 174 removed
# # of subhalos, after the ok survival cut:         736, 0 removed
# # of subhalos removed:                                 175 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     911
# # of subhalos, excluding the main host:           910, 1 removed
# # of subhalos, after the 300 particle mass cut:   895, 15 removed
# # of subhalos, after the ok survival cut:         895, 0 removed
# # of subhalos removed:                                 16 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.5285
#
# ##############################################################################################################################
#
# Halo 73/81: Halo546
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     726
# # of subhalos, excluding the main host:           725, 1 removed
# # of subhalos, after the 300 particle mass cut:   575, 150 removed
# # of subhalos, after the ok survival cut:         575, 0 removed
# # of subhalos removed:                                 151 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     726
# # of subhalos, excluding the main host:           725, 1 removed
# # of subhalos, after the 300 particle mass cut:   710, 15 removed
# # of subhalos, after the ok survival cut:         710, 0 removed
# # of subhalos removed:                                 16 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4400
#
# ##############################################################################################################################
#
# Halo 74/81: Halo561
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     779
# # of subhalos, excluding the main host:           778, 1 removed
# # of subhalos, after the 300 particle mass cut:   631, 147 removed
# # of subhalos, after the ok survival cut:         631, 0 removed
# # of subhalos removed:                                 148 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     779
# # of subhalos, excluding the main host:           778, 1 removed
# # of subhalos, after the 300 particle mass cut:   761, 17 removed
# # of subhalos, after the ok survival cut:         761, 0 removed
# # of subhalos removed:                                 18 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.7021
#
# ##############################################################################################################################
#
# Halo 75/81: Halo572
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     1061
# # of subhalos, excluding the main host:           1060, 1 removed
# # of subhalos, after the 300 particle mass cut:   943, 117 removed
# # of subhalos, after the ok survival cut:         943, 0 removed
# # of subhalos removed:                                 118 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     1061
# # of subhalos, excluding the main host:           1060, 1 removed
# # of subhalos, after the 300 particle mass cut:   1037, 23 removed
# # of subhalos, after the ok survival cut:         1037, 0 removed
# # of subhalos removed:                                 24 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.3043
#
# ##############################################################################################################################
#
# Halo 76/81: Halo574
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     935
# # of subhalos, excluding the main host:           934, 1 removed
# # of subhalos, after the 300 particle mass cut:   753, 181 removed
# # of subhalos, after the ok survival cut:         753, 0 removed
# # of subhalos removed:                                 182 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     935
# # of subhalos, excluding the main host:           934, 1 removed
# # of subhalos, after the 300 particle mass cut:   921, 13 removed
# # of subhalos, after the ok survival cut:         921, 0 removed
# # of subhalos removed:                                 14 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.5206
#
# ##############################################################################################################################
#
# Halo 77/81: Halo600
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     895
# # of subhalos, excluding the main host:           894, 1 removed
# # of subhalos, after the 300 particle mass cut:   735, 159 removed
# # of subhalos, after the ok survival cut:         735, 0 removed
# # of subhalos removed:                                 160 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     895
# # of subhalos, excluding the main host:           894, 1 removed
# # of subhalos, after the 300 particle mass cut:   880, 14 removed
# # of subhalos, after the ok survival cut:         880, 0 removed
# # of subhalos removed:                                 15 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4340
#
# ##############################################################################################################################
#
# Halo 78/81: Halo629
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     808
# # of subhalos, excluding the main host:           807, 1 removed
# # of subhalos, after the 300 particle mass cut:   637, 170 removed
# # of subhalos, after the ok survival cut:         637, 0 removed
# # of subhalos removed:                                 171 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     808
# # of subhalos, excluding the main host:           807, 1 removed
# # of subhalos, after the 300 particle mass cut:   791, 16 removed
# # of subhalos, after the ok survival cut:         791, 0 removed
# # of subhalos removed:                                 17 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.5306
#
# ##############################################################################################################################
#
# Halo 79/81: Halo639
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     847
# # of subhalos, excluding the main host:           846, 1 removed
# # of subhalos, after the 300 particle mass cut:   697, 149 removed
# # of subhalos, after the ok survival cut:         697, 0 removed
# # of subhalos removed:                                 150 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     847
# # of subhalos, excluding the main host:           846, 1 removed
# # of subhalos, after the 300 particle mass cut:   833, 13 removed
# # of subhalos, after the ok survival cut:         833, 0 removed
# # of subhalos removed:                                 14 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4376
#
# ##############################################################################################################################
#
# Halo 80/81: Halo645
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     924
# # of subhalos, excluding the main host:           923, 1 removed
# # of subhalos, after the 300 particle mass cut:   741, 182 removed
# # of subhalos, after the ok survival cut:         741, 0 removed
# # of subhalos removed:                                 183 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     924
# # of subhalos, excluding the main host:           923, 1 removed
# # of subhalos, after the 300 particle mass cut:   909, 14 removed
# # of subhalos, after the ok survival cut:         909, 0 removed
# # of subhalos removed:                                 15 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.4966
#
# ##############################################################################################################################
#
# Halo 81/81: Halo734
# INFALL INTO MAIN HOST:
# # of subhalos before masking:                     676
# # of subhalos, excluding the main host:           675, 1 removed
# # of subhalos, after the 300 particle mass cut:   496, 179 removed
# # of subhalos, after the ok survival cut:         496, 0 removed
# # of subhalos removed:                                 180 removed
#
# INFALL INTO ANYTHING LARGER:
# # of subhalos before masking:                     676
# # of subhalos, excluding the main host:           675, 1 removed
# # of subhalos, after the 300 particle mass cut:   667, 8 removed
# # of subhalos, after the ok survival cut:         667, 0 removed
# # of subhalos removed:                                 9 removed
#
# PREPROCESSING FRACTION:
#   Preprocessed fraction: 0.6109
#
# ##############################################################################################################################
#
# SUITE PREPROCESSING SUMMARY
# Mean per-halo fraction:   50.86%
# Median per-halo fraction: 50.31%
#
# Finished suite: SymphonyCluster (81 halos)
# ========================================================================================================================

# %% [markdown]
# Now defining some functions to plot this infall data in various ways:
# 1. Row 1 is simply a histogram of the subhalo infall data, sorted into snapshot bins. The solid line is for the host infall data, and the dashed line is for the "anything larger" infall data.
# 2. Row 2 is a PDF of the subhalo infall data (basically Row 1 but normalized so that the total probability = 100%).
# 3. Row 3 is a CDF of the subhalo infall data (showing the "fraction of the total").
# 4. Row 4 is Row 2, normalized to the time (snapshot) when the main host accumulated 50% of its peak mass.
# 5. Row 5 is Row 3, normalized to the time (snapshot) when the main host accumulated 50% of its peak mass.

# %%
## functions to plot the raw, un-normalized data

def compute_raw_counts_stats(raw_counts):
    
    mean = np.mean(raw_counts, axis = 0)
    p16_raw = np.percentile(raw_counts, 16, axis = 0)
    p84_raw = np.percentile(raw_counts, 84, axis = 0)

    return mean, p16_raw, p84_raw

def plot_raw_counts(ax, scale_factors, raw_counts, color, fill = False, label = None):

    mean, p16_raw, p84_raw = compute_raw_counts_stats(raw_counts)
    
    ax.plot(scale_factors, mean, color = color, lw = 2)
    
    if fill:
        ax.fill_between(scale_factors, p16_raw, p84_raw, color = color, alpha = 0.25)

#######################################################################################################################

## PDF HELPER FUNCTIONS
def compute_pdf(values, bins):

    values = np.asarray(values)
    values = values[np.isfinite(values)]

    if len(values) == 0:
        return None, None

    hist, edges = np.histogram(values, bins = bins, density = True)

    centers = 0.5 * (edges[:-1] + edges[1:])

    return centers, hist

def compute_pdf_stats_hosts(hosts, key, bins, mask_fn = None):

    pdf_stack = []
    centers = None

    for h in hosts:

        values = np.asarray(h[key])

        if mask_fn is not None:
            mask = mask_fn(h)
            values = values[mask]

        values = values[np.isfinite(values)]

        if len(values) == 0:
            continue

        c, pdf = compute_pdf(values, bins)

        if pdf is None:
            continue

        centers = c
        pdf_stack.append(pdf)

    pdf_stack = np.asarray(pdf_stack)

    if len(pdf_stack) == 0:
        return None, None, None, None

    mean = np.mean(pdf_stack, axis=0)
    p16  = np.percentile(pdf_stack, 16, axis = 0)
    p84  = np.percentile(pdf_stack, 84, axis = 0)

    return centers, mean, p16, p84


def plot_pdf_hosts(ax, hosts, key, bins, color, fill = False, mask_fn = None, label = None):

    centers, mean, p16, p84 = compute_pdf_stats_hosts(hosts, key, bins, mask_fn)

    if mean is None:
        return

    ax.plot(centers, mean, color = color, lw = 2, label = label)

    if fill:
        ax.fill_between(centers, p16, p84, color = color, alpha = 0.25)

#######################################################################################################################

## CDF HELPER FUNCTIONS
def compute_cdf(values, grid):

    values = np.sort(values)
    if len(values) == 0:
        return np.zeros_like(grid)

    cdf = np.arange(1, len(values) + 1) / len(values)
    return np.interp(grid, values, cdf, left = 0, right = 1)


def compute_cdf_stats_hosts(hosts, key, grid, mask_fn = None):

    cdf_stack = []

    for h in hosts:

        values = h[key]

        if mask_fn is not None:
            mask = mask_fn(h)
            values = values[mask]

        values = values[np.isfinite(values)]
        if len(values) == 0:
            continue

        cdf_stack.append(compute_cdf(values, grid))

    cdf_stack = np.array(cdf_stack)

    if len(cdf_stack) == 0:
        return None, None, None

    mean = np.mean(cdf_stack, axis = 0)
    p16  = np.percentile(cdf_stack, 16, axis = 0)
    p84  = np.percentile(cdf_stack, 84, axis = 0)

    return mean, p16, p84

## function to plot the CDFs
def plot_cdf_hosts(ax, hosts, key, grid, color, fill = False, mask_fn = None, label = None):

    mean, p16, p84 = compute_cdf_stats_hosts(hosts, key, grid, mask_fn)

    if mean is None:
        return

    ax.plot(grid, mean, color = color, lw = 2, label = label)
    
    if fill:
        ax.fill_between(grid, p16, p84, color = color, alpha = 0.25)

# %%
## FULL INFALL FIGURE
## Solid lines  --> main host infall
## Dashed lines --> first infall into ANY larger halo

def make_infall_figure_full(suite_data, suite_list, colors, fill):

    nrows = 5
    ncols = len(suite_list)

    fig, ax = plt.subplots(nrows = nrows, ncols = ncols, figsize = (6 * ncols, 4 * nrows), constrained_layout = True, squeeze = False)

    ## predefining grids
    a_grid_raw  = np.linspace(0, 1, 100)
    a_grid_norm = np.linspace(0, 3, 100)

    a_bins_raw = np.linspace(0, 1, 40)
    a_bins_norm = np.linspace(0, 3, 40)


    for i, suite in enumerate(suite_list):

        data = suite_data[suite]
        color = colors[i]
        alt_color = alt_colors[i]
        scale_factors = data["scale_factors"]
        hosts = data["hosts"]

        fractions = np.array([h["preprocessing_fraction"] for h in hosts])
        frac_mean = np.mean(fractions)
        frac_median  = np.median(fractions)


        ## gettings raw counts data:
        host_infall_counts = np.array([h["host_infall_counts"] for h in hosts])
        first_infall_counts = np.array([h["first_infall_counts"] for h in hosts])

#######################################################################################################################

        ## ROW 1: RAW COUNTS

        # main-host infall
        plot_raw_counts(ax[0, i], scale_factors, host_infall_counts, color = color, fill = fill)

        # first infall into any host
        plot_raw_counts(ax[0, i], scale_factors, first_infall_counts, color = alt_color, fill = fill)
        ax[0, i].lines[-1].set_linestyle("--")    # making the "into anything bigger" line dashed

#######################################################################################################################

        ## ROW 2: RAW PDF

        ## same format as before: main host infalls as solid lines, then any-host infalls as dashed lines
        plot_pdf_hosts(ax[1, i], hosts, key = "host_infall_sf", bins = a_bins_raw, color = color, fill = fill)
        plot_pdf_hosts(ax[1, i], hosts, key = "first_infall_sf", bins = a_bins_raw, color = alt_color, fill = fill)
        ax[1, i].lines[-1].set_linestyle("--")

#######################################################################################################################

        ## ROW 3: RAW CDF

        ## you get the gist
        plot_cdf_hosts(ax[2, i], hosts, key = "host_infall_sf", grid = a_grid_raw, color = color, fill = fill)
        plot_cdf_hosts(ax[2, i], hosts, key = "first_infall_sf", grid = a_grid_raw, color = alt_color, fill = fill)
        ax[2, i].lines[-1].set_linestyle("--")

#######################################################################################################################

        ## ROW 4: NORMALIZED PDF

        ## PDF now normalized using a50, otherwise format is the same
        plot_pdf_hosts(ax[3, i], hosts, key = "host_infall_sf_norm", bins = a_bins_norm, color = color, fill = fill)
        plot_pdf_hosts(ax[3, i], hosts, key = "first_infall_sf_norm", bins = a_bins_norm, color = alt_color, fill = fill)
        ax[3, i].lines[-1].set_linestyle("--")

#######################################################################################################################

        ## ROW 5: NORMALIZED CDF

        ## same as above but with the CDF now
        plot_cdf_hosts(ax[4, i], hosts, key = "host_infall_sf_norm", grid = a_grid_norm, color = color, fill = fill)
        plot_cdf_hosts(ax[4, i], hosts, key = "first_infall_sf_norm", grid = a_grid_norm, color = alt_color, fill = fill)
        ax[4, i].lines[-1].set_linestyle("--")

#######################################################################################################################

        ## AXIS LIMITS AND LABELS:

        ax[0, i].set_xlim(0, 1)
        ax[1, i].set_xlim(0, 1)
        ax[2, i].set_xlim(0, 1)
        ax[3, i].set_xlim(0, 3)
        ax[4, i].set_xlim(0, 3)

        ax[0, i].set_title(f"{suite}\nPreprocessing Fraction: {(frac_mean * 100):.2f}%", fontsize = 18)

    ## y-axis labels
    ax[0, 0].set_ylabel("Counts per Snapshot", fontsize = 14)
    ax[1, 0].set_ylabel(r"PDF ($a_{\rm infall}$)", fontsize = 14)
    ax[2, 0].set_ylabel(r"CDF ($a_{\rm infall}$)", fontsize = 14)
    ax[3, 0].set_ylabel(r"PDF ($a_{\rm infall}/a_{50}$)", fontsize = 14)
    ax[4, 0].set_ylabel(r"CDF ($a_{\rm infall}/a_{50}$)", fontsize = 14)

    ## x-labels
    for j in range(ncols):

        ax[0, j].set_xlabel(r"Scale Factor $a(t)$", fontsize = 14)
        ax[1, j].set_xlabel(r"Scale Factor $a(t)$", fontsize = 14)
        ax[2, j].set_xlabel(r"Scale Factor $a(t)$", fontsize = 14)
        ax[3, j].set_xlabel(r"$a_{\rm infall}/a_{50}$", fontsize = 14)
        ax[4, j].set_xlabel(r"$a_{\rm infall}/a_{50}$", fontsize = 14)
    

    return fig, ax

# %%
## make plotting adjustments as needed
fig, ax = make_infall_figure_full(suite_data, suite_list, colors, fill = True)

plt.savefig("ALLCUTS + PREPROCESSING FRACTION.png")
plt.show()
